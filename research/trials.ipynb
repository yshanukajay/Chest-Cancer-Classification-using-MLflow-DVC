# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1l2MjbaDnenMWxgFasVk6j2d5bcWeMbTV/view?usp=drive_link"

# %%
file_ID = url.split('/')[-2]

# %%
file_ID
# Out:
# '1l2MjbaDnenMWxgFasVk6j2d5bcWeMbTV'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_ID, "chest_data.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1l2MjbaDnenMWxgFasVk6j2d5bcWeMbTV
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1l2MjbaDnenMWxgFasVk6j2d5bcWeMbTV&confirm=t&uuid=d6272d30-0f35-4c2e-b940-9e497fd7cd93
# To: c:\Users\2021ICTS28\Desktop\Chest-Cancer-Classification-using-MLflow-DVC\research\chest_data.zip
# 100%|██████████| 124M/124M [00:07<00:00, 16.2MB/s]
# 'chest_data.zip'
